# %% [markdown]
# # Merging the MPST and the ML 20M dataset and create different df for different tasks

# %%
# imports
import pandas as pd
import pickle
# Out:
# /tmp/ipykernel_32601/2023288580.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Loading the MPST DB

# %%
df_mpst = pd.read_pickle('/content/drive/MyDrive/data/raw_data/pmpst_data.pkl')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_mpst.head()
# Out:
#      imdb_id                                          title  \
# 0  tt0057603                        I tre volti della paura
# 1  tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2  tt0033045                     The Shop Around the Corner
# 3  tt0113862                             Mr. Holland's Opus
# 4  tt0086250                                       Scarface
#
#                                        plot_synopsis  \
# 0  Note: this synopsis is for the orginal Italian...
# 1  Two thousand years ago, Nhagruul the Foul, a s...
# 2  Matuschek's, a gift store in Budapest, is the ...
# 3  Glenn Holland, not a morning person by anyone'...
# 4  In May 1980, a Cuban man named Tony Montana (A...
#
#                                                 tags  split synopsis_source
# 0          cult, horror, gothic, murder, atmospheric  train            imdb
# 1                                           violence  train            imdb
# ...

# %%
df_mpst.shape
# Out:
# (14828, 6)

# %% [markdown]
# ## Loading the Movielens DB

# %%
# movielens data

#df_genome_scores = pd.read_csv('/content/drive/MyDrive/raw_data/movielens_20m/genome_scores.csv')

#df_genome_tags = pd.read_csv('/content/drive/MyDrive/raw_data/movielens_20m/genome_tags.csv')

#df_link = pd.read_csv('/content/drive/MyDrive/raw_data/movielens_20m/link.csv')

df_movie = pd.read_csv('/content/drive/MyDrive/raw_data/movielens_20m/movie.csv')

df_rating = pd.read_csv('/content/drive/MyDrive/raw_data/movielens_20m/rating.csv')

df_tag = pd.read_csv('/content/drive/MyDrive/raw_data/movielens_20m/tag.csv')

# %%
#df_genome_scores.head()

# %%
#df_genome_tags.head()

# %%
#df = df_genome_tags.merge(df_genome_scores, how="inner")
#df.head()

# %%
#df.shape

# %%
#df_link.head()

# %%
#df = df_link.merge(df)
#df.head()

# %%
df_movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
pattern = r'\s*\(\d{4}\)$'  # delete (year)

# Remove the year in parentheses using regex
df_movie['title'] = df_movie['title'].str.replace(pattern, '', regex=True)

# %%
df_movie.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#df = df.merge(df_movie, on="movieId", how="inner")

# %%
#df.head()

# %%
#df = df.drop(columns=['imdbId', 'tagId', 'tag', 'relevance', 'genres'])
df_movie = df_movie.drop(columns='genres')

# %%
#df_rating.head()
#df_rating.drop(columns='timestamp', inplace=True)

# %%
#df = df_movie.merge(df_rating, on="movieId", how="inner")

# %%
#df.head()

# %%
#df.shape

# %%
#df_tag.head()
#df_tag.drop(columns='timestamp', inplace=True)

# %%
#df_tag.head()

# %%
#df = df.merge(df_tag, on='movieId', how="inner")

# %%
#df.head()

# %% [markdown]
# ## Merge of both dbs on title

# %%
df_mpst.head()
# Out:
#      imdb_id                                          title  \
# 0  tt0057603                        I tre volti della paura
# 1  tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2  tt0033045                     The Shop Around the Corner
# 3  tt0113862                             Mr. Holland's Opus
# 4  tt0086250                                       Scarface
#
#                                        plot_synopsis  \
# 0  Note: this synopsis is for the orginal Italian...
# 1  Two thousand years ago, Nhagruul the Foul, a s...
# 2  Matuschek's, a gift store in Budapest, is the ...
# 3  Glenn Holland, not a morning person by anyone'...
# 4  In May 1980, a Cuban man named Tony Montana (A...
#
#                                                 tags  split synopsis_source
# 0          cult, horror, gothic, murder, atmospheric  train            imdb
# 1                                           violence  train            imdb
# ...

# %%
df_mpst.drop(columns=['imdb_id','tags', 'split', 'synopsis_source'], inplace=True)

# %%
df_mpst.head()
# Out:
#                                            title  \
# 0                        I tre volti della paura
# 1  Dungeons & Dragons: The Book of Vile Darkness
# 2                     The Shop Around the Corner
# 3                             Mr. Holland's Opus
# 4                                       Scarface
#
#                                        plot_synopsis
# 0  Note: this synopsis is for the orginal Italian...
# 1  Two thousand years ago, Nhagruul the Foul, a s...
# 2  Matuschek's, a gift store in Budapest, is the ...
# 3  Glenn Holland, not a morning person by anyone'...
# 4  In May 1980, a Cuban man named Tony Montana (A...

# %%
df_movie.head()
# Out:
#    movieId                        title
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II

# %%
df = df_mpst.merge(df_movie, on='title', how="inner")

# %% [markdown]
# ## Dropping Duplicates (title and plots)

# %%
df.head()
# Out:
#                 title                                      plot_synopsis  \
# 0  Mr. Holland's Opus  Glenn Holland, not a morning person by anyone'...
# 1            Scarface  In May 1980, a Cuban man named Tony Montana (A...
# 2            Scarface  In May 1980, a Cuban man named Tony Montana (A...
# 3            Scarface  The film opens with a statement that the film ...
# 4            Scarface  The film opens with a statement that the film ...
#
#    movieId
# 0       62
# 1     4262
# 2    25788
# 3     4262
# 4    25788

# %%
df.drop(columns='movieId', inplace=True)

# %%
df.shape
# Out:
# (7974, 2)

# %%
df.head()
# Out:
#                 title                                      plot_synopsis
# 0  Mr. Holland's Opus  Glenn Holland, not a morning person by anyone'...
# 1            Scarface  In May 1980, a Cuban man named Tony Montana (A...
# 2            Scarface  In May 1980, a Cuban man named Tony Montana (A...
# 3            Scarface  The film opens with a statement that the film ...
# 4            Scarface  The film opens with a statement that the film ...

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#                 title                                      plot_synopsis
# 0  Mr. Holland's Opus  Glenn Holland, not a morning person by anyone'...
# 1            Scarface  In May 1980, a Cuban man named Tony Montana (A...
# 3            Scarface  The film opens with a statement that the film ...
# 5          Flightplan  Kyle Pratt (Jodie Foster) is a propulsion engi...
# 6       Little Caesar  Small-time Italian-American criminals Caesar E...

# %%
df.drop_duplicates(subset='title', inplace=True)

# %%
df.shape
# Out:
# (6204, 2)

# %%
df.head()
# Out:
#                 title                                      plot_synopsis
# 0  Mr. Holland's Opus  Glenn Holland, not a morning person by anyone'...
# 1            Scarface  In May 1980, a Cuban man named Tony Montana (A...
# 5          Flightplan  Kyle Pratt (Jodie Foster) is a propulsion engi...
# 6       Little Caesar  Small-time Italian-American criminals Caesar E...
# 7             Savages  The movie begins with a video being shot of me...

# %% [markdown]
# ## Saving as pickle file

# %%
df.to_pickle('/content/drive/MyDrive/raw_data/films_with_plot_complete.pkl')

# %%
df_rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %% [markdown]
# # **Creating a df with userId, rating and title**

# %%
#merge a second dataframe
# userID, rating, title

# %% [markdown]
# ## Reload merge of df_mpst and df_movie for movie_id

# %%
df_2 = df_mpst.merge(df_movie, on='title', how="inner")

# %%
df_2.head()
# Out:
#      imdb_id               title  \
# 0  tt0113862  Mr. Holland's Opus
# 1  tt0086250            Scarface
# 2  tt0086250            Scarface
# 3  tt0023427            Scarface
# 4  tt0023427            Scarface
#
#                                        plot_synopsis  \
# 0  Glenn Holland, not a morning person by anyone'...
# 1  In May 1980, a Cuban man named Tony Montana (A...
# 2  In May 1980, a Cuban man named Tony Montana (A...
# 3  The film opens with a statement that the film ...
# 4  The film opens with a statement that the film ...
#
#                                                 tags  split synopsis_source  \
# 0             inspiring, romantic, stupid, feel-good  train            imdb
# 1  cruelty, murder, dramatic, cult, violence, atm...    val            imdb
# 2  cruelty, murder, dramatic, cult, violence, atm...    val            imdb
# 3                                   violence, murder  train            imdb
# ...

# %%
df_2 = df_2.drop(columns=["imdb_id", "plot_synopsis", "tags", "split", "synopsis_source"]).drop_duplicates()

# %%
df_2.head()
# Out:
#                 title  movieId
# 0  Mr. Holland's Opus       62
# 1            Scarface     4262
# 2            Scarface    25788
# 5          Flightplan    37727
# 6       Little Caesar    25773

# %%
df_2 = df_2.drop_duplicates(subset='title')

# %%
df_2.head()
# Out:
#                 title  movieId
# 0  Mr. Holland's Opus       62
# 1            Scarface     4262
# 5          Flightplan    37727
# 6       Little Caesar    25773
# 7             Savages    56956

# %% [markdown]
# ## Preparing Movielens df_rating

# %%
df_rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
df_rating.drop(columns="timestamp", inplace=True)

# %%
df_rating.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %% [markdown]
# ## Merging df and ratings

# %%
df_rating_title = df_2.merge(df_rating, on="movieId", how="inner")

# %%
df_rating_title.head(20)
# Out:
#                  title  movieId  userId  rating
# 0   Mr. Holland's Opus       62       2     5.0
# 1   Mr. Holland's Opus       62       5     5.0
# 2   Mr. Holland's Opus       62       6     5.0
# 3   Mr. Holland's Opus       62      14     4.0
# 4   Mr. Holland's Opus       62      19     5.0
# 5   Mr. Holland's Opus       62      24     3.0
# 6   Mr. Holland's Opus       62      38     5.0
# 7   Mr. Holland's Opus       62      46     4.0
# 8   Mr. Holland's Opus       62      48     4.0
# 9   Mr. Holland's Opus       62      53     1.0
# 10  Mr. Holland's Opus       62      69     3.0
# 11  Mr. Holland's Opus       62      75     4.0
# 12  Mr. Holland's Opus       62      80     4.0
# 13  Mr. Holland's Opus       62      91     3.5
# 14  Mr. Holland's Opus       62      93     5.0
# 15  Mr. Holland's Opus       62     114     4.0
# 16  Mr. Holland's Opus       62     126     4.0
# 17  Mr. Holland's Opus       62     130     4.0
# 18  Mr. Holland's Opus       62     132     3.0
# ...

# %%
df_rating_title.shape
# Out:
# (12335729, 4)

# %%
df_rating_title.to_pickle('/content/drive/MyDrive/raw_data/title_movieId_userId_rating.pkl')

# %% [markdown]
# # **Creating a df with movieId, title and plot_synopsis**

# %% [markdown]
# ## Reload MPST for title, plot_synopsis and movieId

# %%
df_3 = df_mpst.merge(df_movie, on='title', how="inner")

# %%
df_3 = df_3.drop(columns=["imdb_id", "tags", "split", "synopsis_source"]).drop_duplicates()

# %%
df_3 = df_3.drop_duplicates(subset='title')

# %%
df_3.head()
# Out:
#                 title                                      plot_synopsis  \
# 0  Mr. Holland's Opus  Glenn Holland, not a morning person by anyone'...
# 1            Scarface  In May 1980, a Cuban man named Tony Montana (A...
# 5          Flightplan  Kyle Pratt (Jodie Foster) is a propulsion engi...
# 6       Little Caesar  Small-time Italian-American criminals Caesar E...
# 7             Savages  The movie begins with a video being shot of me...
#
#    movieId
# 0       62
# 1     4262
# 5    37727
# 6    25773
# 7    56956

# %%
df_3.shape
# Out:
# (6204, 3)

# %%
df_3.to_pickle('/content/drive/MyDrive/raw_data/title_plot_movieId.pkl')
